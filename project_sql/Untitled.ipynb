# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("top_paying_jobs.csv")
df.head()
# Out:
#    job_id                          job_title firm_name  salary_year_avg  \
# 0  552322  Associate Director- Data Insights      AT&T         255829.5
# 1  552322  Associate Director- Data Insights      AT&T         255829.5
# 2  552322  Associate Director- Data Insights      AT&T         255829.5
# 3  552322  Associate Director- Data Insights      AT&T         255829.5
# 4  552322  Associate Director- Data Insights      AT&T         255829.5
#
#        skills
# 0         sql
# 1      python
# 2           r
# 3       azure
# 4  databricks

# %%
x = df.skills.value_counts()

# %%
x
# Out:
# skills
# sql           8
# python        7
# tableau       6
# r             4
# snowflake     3
# pandas        3
# excel         3
# azure         2
# bitbucket     2
# go            2
# oracle        2
# power bi      2
# confluence    2
# gitlab        2
# atlassian     2
# jira          2
# aws           2
# numpy         2
# jenkins       1
# sap           1
# crystal       1
# flow          1
# hadoop        1
# powerpoint    1
# jupyter       1
# pyspark       1
# databricks    1
# git           1
# Name: count, dtype: int64
